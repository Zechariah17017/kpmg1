# %% [markdown]
# # KPMG DATA INSIGHTS
#  #### Data Exploration, Model Development, Interpretation

# %%
#Get all packages needed
import pandas as pd
import numpy as np
import datetime
from matplotlib.ticker import FuncFormatter
import matplotlib.pyplot as plt
import warnings
import math as ma
warnings.filterwarnings("ignore")

# %%
kmpgex = pd.ExcelFile('KPMG_final1.xlsx')
kmpgex.sheet_names
df = pd.read_excel('KPMG_final1.xlsx', sheetname="CustomerDemographic")
#list(df)

# %%
# rename for easier analysis
df.rename(columns={"Note: The data and information in this document is reflective of a hypothetical situation and client. This document is to be used for KPMG Virtual Internship purposes only. ":"customer_id"}, inplace = True)
df.rename(columns={"Unnamed: 1":"fname",
                   "Unnamed: 2":"lname",
                   "Unnamed: 3":"gender",
                   "Unnamed: 4":"3y_bike_purchases",
                   "Unnamed: 5":"DOB",
                   "Unnamed: 6":"JT"}, inplace = True)
df.rename(columns={"Unnamed: 7":"Category",
                   "Unnamed: 8":"wealth_segement",
                   "Unnamed: 9":"D_Indicator",
                   "Unnamed: 10":"default",
                   "Unnamed: 11":"owns_car",
                   "Unnamed: 12":"tencure"}, inplace = True)
df=df.iloc[1:]
df
# Out:
#      customer_id           fname          lname  gender 3y_bike_purchases  \
# 2              2             Eli        Bockman    Male                81
# 3              3           Arlin         Dearle    Male                61
# 4              4          Talbot            NaN    Male                33
# 5              5  Sheila-kathryn         Calton  Female                56
# 6              6            Curr      Duckhouse    Male                35
# 7              7            Fina         Merali  Female                 6
# 8              8             Rod          Inder    Male                31
# 9              9            Mala           Lind  Female                97
# 10            10        Fiorenze        Birdall  Female                49
# 11            11           Uriah         Bisatt    Male                99
# 12            12         Sawyere       Flattman    Male                58
# 13            13        Gabriele       Norcross    Male                38
# 14            14        Rayshell       Kitteman  Female                85
# 15            15          Erroll         Radage    Male                91
# 16            16          Harlin           Parr    Male                38
# 17            17           Heath        Faraday    Male                57
# 18            18          Marjie        Neasham  Female                79
# 19            19          Sorcha         Keyson  Female                76
# 20            20          Basile          Firth    Male                72
# 21            21            Mile       Cammocke    Male                74
# 22            22         Deeanne       Durtnell  Female                79
# 23            23            Olav          Polak    Male                43
# 24            24             Kim         Skpsey  Female                55
# 25            25           Geoff          Assaf    Male                72
# 26            26           Trixi       Ginnelly  Female                12
# 27            27          Garvin          Klees    Male                37
# 28            28             Fee        Zellmer    Male                 5
# 29            29            Mona       Sancraft  Female                62
# 30            30         Darrick      Helleckas    Male                18
# 31            31            Star         Praton  Female                 3
# ...          ...             ...            ...     ...               ...
# 3971        3971         Analise         Asbrey  Female                 2
# 3972        3972       Maribelle       Schaffel  Female                 6
# 3973        3973         Carolan          Jorez  Female                24
# 3974        3974           Misha        Ranklin  Female                82
# 3975        3975      Dianemarie        Kidgell  Female                 2
# 3976        3976          Gretel       Chrystal  Female                 0
# 3977        3977        Katrinka  Van der Beken  Female                31
# 3978        3978         Kathlin         Robker  Female                 4
# 3979        3979           Kleon           Adam    Male                67
# 3980        3980            Nils      McGebenay    Male                41
# 3981        3981       Konstance          Draye  Female                34
# 3982        3982         Maurita       O'Kinedy  Female                89
# 3983        3983          Jarred          Lyste    Male                19
# 3984        3984         Thadeus         Buxsey    Male                74
# 3985        3985           Caryn        Padbury  Female                44
# 3986        3986          Oralle       Petrello  Female                 1
# 3987        3987          Beckie        Wakeham  Female                18
# 3988        3988       Ammamaria       Ashburne  Female                97
# 3989        3989         Nicolas        Burdass    Male                75
# 3990        3990         Reynard         Hagger    Male                99
# 3991        3991           Rolph       Sweetnam    Male                61
# 3992        3992         Germain        Tireman    Male                99
# 3993        3993            Andi        Dumelow  Female                 6
# 3994        3994         Stephie          Byars  Female                 5
# 3995        3995           Rusty         Iapico    Male                93
# 3996        3996         Rosalia       Halgarth  Female                 8
# 3997        3997          Blanch         Nisuis  Female                87
# 3998        3998          Sarene        Woolley       U                60
# 3999        3999       Patrizius            NaN    Male                11
# 4000        4000           Kippy        Oldland    Male                76
#
#                       DOB                                    JT  \
# 2     1980-12-16 00:00:00                Administrative Officer
# 3     1954-01-20 00:00:00                    Recruiting Manager
# 4     1961-10-03 00:00:00                                   NaN
# 5     1977-05-13 00:00:00                         Senior Editor
# 6     1966-09-16 00:00:00                                   NaN
# 7     1976-02-23 00:00:00                                   NaN
# 8     1962-03-30 00:00:00                       Media Manager I
# 9     1973-03-10 00:00:00  Business Systems Development Analyst
# 10    1988-10-11 00:00:00               Senior Quality Engineer
# 11    1954-04-30 00:00:00                                   NaN
# 12    1994-07-21 00:00:00                Nuclear Power Engineer
# 13    1955-02-15 00:00:00                           Developer I
# 14    1983-03-25 00:00:00                     Account Executive
# 15    2000-07-13 00:00:00                      Junior Executive
# 16    1977-02-27 00:00:00                      Media Manager IV
# 17    1962-03-19 00:00:00                       Sales Associate
# 18    1967-07-06 00:00:00                             Professor
# 19    2001-04-15 00:00:00                   Geological Engineer
# 20    1980-08-13 00:00:00                       Project Manager
# 21    1980-09-20 00:00:00                   Safety Technician I
# 22    1962-12-10 00:00:00                                   NaN
# 23    1995-02-10 00:00:00                                   NaN
# 24    1977-12-03 00:00:00                  Research Assistant I
# 25    1976-12-02 00:00:00              Accounting Assistant III
# 26    1978-06-10 00:00:00                                Editor
# 27    1978-09-25 00:00:00                        Research Nurse
# 28    1973-09-30 00:00:00               Senior Quality Engineer
# 29    1968-06-22 00:00:00                 Safety Technician III
# 30    1961-10-18 00:00:00                                   NaN
# 31    1962-11-24 00:00:00                  Staff Accountant III
# ...                   ...                                   ...
# 3971  1979-01-14 00:00:00            Desktop Support Technician
# 3972  1979-03-28 00:00:00                                   NaN
# 3973  1963-07-13 00:00:00                                Editor
# 3974  1961-02-11 00:00:00                      Technical Writer
# 3975  1971-08-11 00:00:00            Administrative Assistant I
# 3976  1957-11-20 00:00:00                      Internal Auditor
# 3977  1965-08-21 00:00:00                    Biostatistician II
# 3978  1972-03-02 00:00:00                          Developer II
# 3979  1974-07-13 00:00:00                                   NaN
# 3980  1964-01-16 00:00:00                        Web Designer I
# 3981  1994-09-10 00:00:00            Quality Control Specialist
# 3982  1962-06-02 00:00:00                       General Manager
# 3983  1965-04-21 00:00:00                      Graphic Designer
# 3984  1960-02-16 00:00:00                             Librarian
# 3985  1998-06-21 00:00:00                      Web Developer IV
# 3986  1976-12-01 00:00:00                         Social Worker
# 3987  1964-05-29 00:00:00                                   NaN
# 3988  1994-07-14 00:00:00              Automation Specialist IV
# 3989  1999-06-23 00:00:00              Environmental Specialist
# 3990  1998-03-05 00:00:00            Desktop Support Technician
# 3991  1985-08-06 00:00:00                 Chief Design Engineer
# 3992  1980-04-02 00:00:00             Database Administrator IV
# 3993  1974-12-05 00:00:00                             Librarian
# 3994  1989-04-07 00:00:00          Structural Analysis Engineer
# 3995  1975-12-12 00:00:00                       Staff Scientist
# 3996  1975-08-09 00:00:00                 VP Product Management
# 3997  2001-07-13 00:00:00                       Statistician II
# 3998                  NaN                     Assistant Manager
# 3999  1973-10-24 00:00:00                                   NaN
# 4000  1991-11-05 00:00:00                  Software Engineer IV
#
#                 Category    wealth_segement D_Indicator  \
# 2     Financial Services      Mass Customer           N
# 3               Property      Mass Customer           N
# 4                     IT      Mass Customer           N
# 5                    NaN  Affluent Customer           N
# 6                 Retail     High Net Worth           N
# 7     Financial Services  Affluent Customer           N
# 8                    NaN      Mass Customer           N
# 9            Argiculture  Affluent Customer           N
# 10    Financial Services      Mass Customer           N
# 11              Property      Mass Customer           N
# 12         Manufacturing      Mass Customer           N
# 13    Financial Services     High Net Worth           N
# 14    Financial Services  Affluent Customer           N
# 15         Manufacturing      Mass Customer           N
# 16                   NaN      Mass Customer           N
# 17                   NaN  Affluent Customer           N
# 18                   NaN  Affluent Customer           N
# 19         Manufacturing     High Net Worth           N
# 20         Manufacturing      Mass Customer           N
# 21         Manufacturing  Affluent Customer           N
# 22                    IT      Mass Customer           N
# 23                   NaN     High Net Worth           N
# 24           Argiculture      Mass Customer           N
# 25    Financial Services      Mass Customer           N
# 26    Financial Services      Mass Customer           N
# 27                Health      Mass Customer           N
# 28                Health  Affluent Customer           N
# 29         Manufacturing      Mass Customer           N
# 30                    IT  Affluent Customer           N
# 31    Telecommunications     High Net Worth           N
# ...                  ...                ...         ...
# 3971  Financial Services     High Net Worth           N
# 3972              Retail      Mass Customer           N
# 3973       Manufacturing     High Net Worth           N
# 3974                 NaN  Affluent Customer           N
# 3975       Entertainment  Affluent Customer           N
# 3976                 NaN  Affluent Customer           N
# 3977       Manufacturing      Mass Customer           N
# 3978  Financial Services      Mass Customer           N
# 3979  Financial Services      Mass Customer           N
# 3980       Manufacturing      Mass Customer           N
# 3981              Health      Mass Customer           N
# 3982       Manufacturing      Mass Customer           N
# 3983                 NaN      Mass Customer           N
# 3984       Entertainment  Affluent Customer           N
# 3985            Property      Mass Customer           N
# 3986              Health      Mass Customer           N
# 3987         Argiculture      Mass Customer           N
# 3988              Health      Mass Customer           N
# 3989         Argiculture  Affluent Customer           N
# 3990              Health     High Net Worth           N
# 3991       Manufacturing      Mass Customer           N
# 3992       Manufacturing  Affluent Customer           N
# 3993       Entertainment      Mass Customer           N
# 3994       Manufacturing  Affluent Customer           N
# 3995       Manufacturing      Mass Customer           N
# 3996              Health      Mass Customer           N
# 3997       Manufacturing     High Net Worth           N
# 3998                  IT     High Net Worth           N
# 3999       Manufacturing  Affluent Customer           N
# 4000                 NaN  Affluent Customer           N
#
#                                                 default owns_car tencure
# 2                          <script>alert('hi')</script>      Yes      16
# 3                                   2018-02-01 00:00:00      Yes      15
# 4     () { _; } >_[$($())] { touch /tmp/blns.shellsh...       No       7
# 5                                                   NIL      Yes       8
# 6                                              ðµ ð ð ð      Yes      13
# 7                                             â°â´âµâââ      Yes      11
# 8                               (â¯Â°â¡Â°ï¼â¯ï¸µ â»ââ»)       No       7
# 9                                                   0/0      Yes       8
# 10                                                 ð©ð½      Yes      20
# 11                                   ÅâÂ´Â®â Â¥Â¨ËÃ¸Ïââ       No       9
# 12                                                  nil       No       8
# 13                                                 -100      Yes       8
# 14                                               â°â´âµ       No       6
# 15                                                    ð       No       1
# 16    1000000000000000049861653971908893017010268485...      Yes      18
# 17                     ï¾ï½¥â¿ã¾â²(ï½¡ââ¿âï½¡)â±â¿ï½¥ï¾      Yes      15
# 18                                    Î©âÃ§ââ«ËÂµâ¤â¥Ã·       No      11
# 19                                      ÅâÂ´â°ËÃÂ¨ËÃâââ       No       1
# 20                                                 ð©ð½       No      11
# 21                                                 -100      Yes      16
# 22                                               ï¼ï¼ï¼       No      11
# 23                                  2018-02-01 00:00:00      Yes       1
# 24           ../../../../../../../../../../../etc/hosts      Yes      15
# 25               ×Ö¸×Ö°×ªÖ¸×testØ§ÙØµÙØ­Ø§Øª Ø§ÙØªÙØ­ÙÙ      Yes      21
# 26                                           <>?:"{}|_+      Yes      16
# 27                                                ''''"      Yes      12
# 28                                           ,./;'[]\-=      Yes      21
# 29         () { 0; }; touch /tmp/blns.shellshock1.fail;       No      19
# 30                                   ì¬íê³¼íì ì´íì°êµ¬ì      Yes       6
# 31                                         testâ testâ«      Yes      14
# ...                                                 ...      ...     ...
# 3971                                                NaN       No      16
# 3972  Ì¦HÍÌ¬Ì¤ÌÌ¤eÍ ÍÌÌ¥ÌÌ»ÍÌwÌhÌÌ¯ÍoÌÍÌÍÌ±Ì® ÒÌºÌÌÌ...       No       8
# 3973                                  ð¾ ð ð ð ð ð ð ð§       No      17
# 3974                                                  1      Yes       9
# 3975                                                NIL       No      18
# 3976                                            '"''''"      Yes      13
# 3977                                 ÅâÂ´Â®â Â¥Â¨ËÃ¸Ïââ      Yes      16
# 3978                                                NIL       No       5
# 3979                   â¤ï¸ ð ð ð ð ð ð ð ð ð ð ð ð ð ð      Yes      18
# 3980                                                 â¡       No      12
# 3981  ËÉnbá´lÉ ÉuÆÉÉ¯ ÇÉ¹olop ÊÇ ÇÉ¹oqÉl Ên Êunpá´pá...       No       1
# 3982                                                  1      Yes      12
# 3983  Ì¦HÍÌ¬Ì¤ÌÌ¤eÍ ÍÌÌ¥ÌÌ»ÍÌwÌhÌÌ¯ÍoÌÍÌÍÌ±Ì® ÒÌºÌÌÌ...      Yes       9
# 3984                           âð¿ ðªð¿ ðð¿ ðð¿ ðð¿ ðð¿       No      10
# 3985                                                0/0       No       4
# 3986                                                NaN       No      21
# 3987                                                  á       No       7
# 3988                                                 â¡      Yes       1
# 3989                                                âââ      Yes       1
# 3990                                                  0       No       1
# 3991                                                 "'      Yes      13
# 3992  Ø«Ù ÙÙØ³ Ø³ÙØ·Øª ÙØ¨Ø§ÙØªØ­Ø¯ÙØ¯Ø, Ø¬Ø²ÙØ±ØªÙ ...      Yes      18
# 3993                                                 á        No      10
# 3994                                               -100       No      12
# 3995                                                 á       Yes      14
# 3996                                               -100       No      19
# 3997                                           â¦testâ§      Yes       1
# 3998                                                NaN       No     NaN
# 3999                             Â¡â¢Â£Â¢âÂ§Â¶â¢ÂªÂºââ       Yes      10
# 4000                                                0/0       No      11
#
# [3999 rows x 13 columns]

# %%
def check_NA():
    ret = []
    temp = list(df)
    for each in temp:
        ret.append(df[each].isna().sum())
    return ret

NaNlist = check_NA()
print(NaNlist, len(NaNlist))
# need to check columns
check = []
k     = -1
for i in NaNlist:
    k += 1
    if i > 0:
        check.append(k)
def check_unique():
    temp = list(df)
    mydict = {}
    for i in range(3, 13):
        ct = 0
        if NaNlist[i] > 0:
            ct = len(df[temp[i]].unique()) - 1
        else:
            ct = len(df[temp[i]].unique())
        mydict[temp[i]] = (ct, df[temp[i]].unique())
    return mydict
# Out:
# [0, 0, 125, 0, 0, 87, 506, 656, 0, 0, 302, 0, 87] 13

# %%
#array(['F', 'Male', 'Female', 'U', 'Femal', 'M'] from KPMG_VI.py
gender = [0,0,0] #first is Female, second if Male, third is Unknown
for each in df['gender']:
    if each[0] == "F":
        gender[0] += 1
    elif each[0] == "M":
        gender[1] += 1
    else:
        gender[2] += 1

print(gender)
def gf(x, pos):
    #'The two args are the value and gender'
    return int(x)

bike = [0,0,0]
bike[0] += df['3y_bike_purchases'][df['gender'] == 'Female'].sum() + df['3y_bike_purchases'][df['gender'] == 'F'].sum()
bike[1] += df['3y_bike_purchases'][df['gender'] == 'Male'].sum() + df['3y_bike_purchases'][df['gender'] == 'M'].sum()
bike[2] += df['3y_bike_purchases'][df['gender'] == 'U'].sum()

grapho = [gender[0], bike[0], gender[1], bike[1], gender[2], bike[2]]
graphl = [gender[0]*10, bike[0], gender[1]*10, bike[1], gender[2]*10, bike[2]]
colorr = (0.3,0.1,0.4,0.6)
#scale up gender by 10 for easier visualization
formatter = FuncFormatter(gf)
x = np.arange(6)
fig, ax = plt.subplots()
ax.set_ylabel('Number of people')
ax.yaxis.set_major_formatter(formatter)
plt.bar(x, graphl, color = colorr)
for i in range(len(gender*2)):
    plt.text(x = i-0.2, y = graphl[i]+0.1, s = grapho[i], size = 10)

plt.xticks(x, ('Female', "F's P", 'Male', "M's P", 'Unknown', "U's P"))
# Out:
# [2038, 1873, 88]
# ([<matplotlib.axis.XTick at 0x24c94720278>,
#   <matplotlib.axis.XTick at 0x24c94720780>,
#   <matplotlib.axis.XTick at 0x24c94732cc0>,
#   <matplotlib.axis.XTick at 0x24c953fa828>,
#   <matplotlib.axis.XTick at 0x24c953fae10>,
#   <matplotlib.axis.XTick at 0x24c953fc518>],
#  <a list of 6 Text xticklabel objects>)

# %%
avg  = [0,0,0]
ss   = sum(bike)
for i in range(len(avg)):
    avg[i] += round(bike[i]/ss,3) 

x1 = np.arange(3)
fig1, ax1 = plt.subplots()
ax1.set_ylabel('Percentage bikes bought by gender')
plt.bar(x1, avg, color = colorr)
for i in range(len(avg)):
    plt.text(x = i-0.15, y = avg[i], s = avg[i], size = 10)

plt.xticks(x1, ('Female', 'Male', 'Unknown'))
# Out:
# ([<matplotlib.axis.XTick at 0x24c95403518>,
#   <matplotlib.axis.XTick at 0x24c953ffc88>,
#   <matplotlib.axis.XTick at 0x24c953ff9b0>],
#  <a list of 3 Text xticklabel objects>)

# %%
# #Analyze on the age vs bikes bought
# #Needs to transform
# dti = pd.to_datetime(['1/1/2018', np.datetime64('2018-01-01'), datetime.datetime(2018, 1, 1)])
# print(df["DOB"][1].ctime().split(" ")[4])
# df["Age"] = 0
# lenn = len(df["DOB"])
# k    = 0
# for i in range(1, lenn):
#     #type is date
#     if isinstance(df["DOB"][i], datetime.date):
#         tl = len(df["DOB"][i].ctime().split(" "))
#         df["Age"][i] += int(2019 - int(df["DOB"][i].ctime().split(" ")[tl-1]))
#     #type is string
#     elif isinstance(df["DOB"][i], str):
#         tl = len(df["DOB"][i].split("-"))
#         df["Age"][i] += int(2019 - int(df["DOB"][i].split("-")[tl-1])) 
#     #time is float: means it's nan value so do nothing
# print(k)

# %%
#same index as above
ngenage = [0,0,0]
j       = 1
ss      = 0
stdv    = []
for each in df['gender']:
    if each[0] == "F" and df['Age'][j] != 0:
        ss   += df['Age'][j]
        stdv.append((df['Age'][j]))
        ngenage[0] += 1
    elif each[0] == "M" and df['Age'][j] != 0:
        ss += df['Age'][j]
        stdv.append((df['Age'][j]))
        ngenage[1] += 1
    elif df['Age'][j] != 0: 
        ss += df['Age'][j]
        stdv.append((df['Age'][j]))
        ngenage[2] += 1
    j += 1
print(ss)
print(ngenage) # as we can see, unknonwn gender will unlikely to have age, don't care about gender U
#average age not counting 0 is 
mean_val = round(ss/sum(ngenage),0)
print(mean_val)
stdv_val = round(ma.sqrt(1/(sum(ngenage)-1)*sum((stdv - (ss/sum(ngenage)))**2)),0)
print(stdv_val)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-c6d72088a202> in <module>()
#       9         stdv.append((df['Age'][j]))
#      10         ngenage[0] += 1
# ---> 11     elif each[0] == "M" and df['Age'][j] != 0:
#      12         ss += df['Age'][j]
#      13         stdv.append((df['Age'][j]))
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'

# %%
#pruchases from age 42 - 34/2, 42, 42 + 34/2 
age_dict = {}
f1  = []
bf1 = []
f2  = []
bf2 = []
f3  = []
bf3 = []
f4  = []
bf4 = []
m1  = []
bm1 = []
m2  = []
bm2 = []
m3  = []
bm3 = []
m4  = []
bm4 = []
fq = mean_val - stdv_val/2
sq = mean_val
tq = mean_val + stdv_val/2
print(fq, sq, tq)
jjj = 1
for each in df['gender']:
    temp = int(df['Age'][jjj])
    bkt  = int(df['3y_bike_purchases'][jjj])
    if each[0] == "F" and temp != 0:
        if(temp <= fq):
            f1.append(temp)
            bf1.append(bkt)
        elif(fq < temp and temp <= sq):
            f2.append(temp)
            bf2.append(bkt)
        elif(sq < temp and temp <= tq):
            f3.append(temp)
            bf3.append(bkt)
        elif(tq < temp):
            f4.append(temp)
            bf4.append(bkt)
    elif each[0] == "M" and temp != 0:
        if(temp <= fq):
            m1.append(temp)
            bm1.append(bkt)
        elif(fq < temp and temp <= sq):
            m2.append(temp)
            bm2.append(bkt)
        elif(sq < temp and temp <= tq):
            m3.append(temp)
            bm3.append(bkt)
        elif(tq < temp):
            m4.append(temp)
            bm4.append(bkt)
    jjj += 1
dtt = {"Female1":f1,
       "Female2":f2,
       "Female3":f3,
       "Female4":f4,
       "Male1":m1,
       "Male2":m2,
       "Male3":m3,
       "Male4":m4,
      }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-64761244c3e4> in <module>()
#      17 m4  = []
#      18 bm4 = []
# ---> 19 fq = mean_val - stdv_val/2
#      20 sq = mean_val
#      21 tq = mean_val + stdv_val/2
#
# NameError: name 'mean_val' is not defined

# %%
print(len(dtt["Female1"]), len(dtt["Female2"]), len(dtt["Female3"]), len(dtt["Female4"]))
print(len(dtt["Male1"]), len(dtt["Male2"]), len(dtt["Male3"]), len(dtt["Male4"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-ad9e870bff6a> in <module>()
# ----> 1 print(len(dtt["Female1"]), len(dtt["Female2"]), len(dtt["Female3"]), len(dtt["Female4"]))
#       2 print(len(dtt["Male1"]), len(dtt["Male2"]), len(dtt["Male3"]), len(dtt["Male4"]))
#
# NameError: name 'dtt' is not defined

# %%
graphgen = [len(dtt["Female1"]), len(dtt["Male1"]), len(dtt["Female2"]), len(dtt["Male2"]), len(dtt["Female3"]), len(dtt["Male3"]), len(dtt["Female4"]), len(dtt["Male4"])]
colorr = (0.7,0.7,0.7,0.7)

x2 = np.arange(8)
fig2, ax2 = plt.subplots()
ax2.set_ylabel('Number of people')
plt.bar(x2, graphgen, color = colorr)
for i in range(len(graphgen)):
    plt.text(x = i-0.2, y = graphgen[i]+0.1, s = graphgen[i], size = 10)

plt.xticks(x2, ('Fq1', "Mq1", 'Fq2', "Mq2", 'Fq3', "Mq3", 'Fq4', "Mq4"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6c371a971a6e> in <module>()
# ----> 1 graphgen = [len(dtt["Female1"]), len(dtt["Male1"]), len(dtt["Female2"]), len(dtt["Male2"]), len(dtt["Female3"]), len(dtt["Male3"]), len(dtt["Female4"]), len(dtt["Male4"])]
#       2 colorr = (0.7,0.7,0.7,0.7)
#       3
#       4 x2 = np.arange(8)
#       5 fig2, ax2 = plt.subplots()
#
# NameError: name 'dtt' is not defined

# %%
#check_unique()["Category"]
df["Category"].value_counts()
# Out:
# Manufacturing         799
# Financial Services    774
# Health                601
# Retail                358
# Property              267
# IT                    223
# Entertainment         136
# Argiculture           113
# Telecommunications     72
# Name: Category, dtype: int64

# %%
val = [799, 774, 602, 358, 267, 223, 136, 113, 72]
colorr = (0.2,0.3,0.4,0.5)

x3 = np.arange(9)
fig3, ax3 = plt.subplots()
ax3.set_ylabel('Number of people')
plt.bar(x3, val, color = colorr, width = 0.4)
for i in range(len(val)):
    plt.text(x = i-0.25, y = val[i]+0.1, s = val[i], size = 10)

plt.xticks(x3, ("Manu", "Finance", "Health", "Retail", "Property", "IT", "Entertain", "Agri", "Telecom")
# Out:
#   File "<ipython-input-21-d1a70a9f9b26>", line 10
#     plt.xticks(x3, ("Manu", "Finance", "Health", "Retail", "Property", "IT", "Entertain", "Agri", "Telecom")
#                                                                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
check_unique()["wealth_segement"]
df["wealth_segement"].value_counts()
# Out:
# Mass Customer        1999
# High Net Worth       1021
# Affluent Customer     979
# Name: wealth_segement, dtype: int64

# %%
jjj = 1
wsm = {"q1":[], "q2":[], "q3":[], "q4":[]}
wsh = {"q1":[], "q2":[], "q3":[], "q4":[]}
wsa = {"q1":[], "q2":[], "q3":[], "q4":[]}

for each in df['wealth_segement']:
    temp = int(df['Age'][jjj])
    if each[0] == "M" and temp != 0:
        if(temp <= fq):
            wsm["q1"].append(temp)
        elif(fq < temp and temp <= sq):
            wsm["q2"].append(temp)
        elif(sq < temp and temp <= tq):
            wsm["q3"].append(temp)
        elif(tq < temp):
            wsm["q4"].append(temp)
    elif each[0] == "H" and temp != 0:
        if(temp <= fq):
            wsh["q1"].append(temp)
        elif(fq < temp and temp <= sq):
            wsh["q2"].append(temp)
        elif(sq < temp and temp <= tq):
            wsh["q3"].append(temp)
        elif(tq < temp):
            wsh["q4"].append(temp)
    elif each[0] == "A" and temp != 0:
        if(temp <= fq):
            wsa["q1"].append(temp)
        elif(fq < temp and temp <= sq):
            wsa["q2"].append(temp)
        elif(sq < temp and temp <= tq):
            wsa["q3"].append(temp)
        elif(tq < temp):
            wsa["q3"].append(temp)
    jjj += 1
print(len(wsm["q1"]), len(wsm["q2"]), len(wsm["q3"]), len(wsm["q4"]))
print(len(wsh["q1"]), len(wsh["q2"]), len(wsh["q3"]), len(wsh["q4"]))
print(len(wsa["q1"]), len(wsa["q2"]), len(wsa["q3"]), len(wsa["q4"]))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-36a8e33bad33> in <module>()
#       5
#       6 for each in df['wealth_segement']:
# ----> 7     temp = int(df['Age'][jjj])
#       8     if each[0] == "M" and temp != 0:
#       9         if(temp <= fq):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2683             return self._getitem_multilevel(key)
#    2684         else:
# -> 2685             return self._getitem_column(key)
#    2686
#    2687     def _getitem_column(self, key):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2690         # get column
#    2691         if self.columns.is_unique:
# -> 2692             return self._get_item_cache(key)
#    2693
#    2694         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2484         res = cache.get(item)
#    2485         if res is None:
# -> 2486             values = self._data.get(item)
#    2487             res = self._box_item_values(item, values)
#    2488             cache[item] = res
#
# ~\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
# -> 3065                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3066
#    3067         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'

# %%
N = 4
wsmtp = [len(wsm["q1"]), len(wsm["q2"]), len(wsm["q3"]), len(wsm["q4"])]
wshtp = [len(wsh["q1"]), len(wsh["q2"]), len(wsh["q3"]), len(wsh["q4"])]
wsatp = [len(wsa["q1"]), len(wsa["q2"]), len(wsa["q3"]), len(wsa["q4"])]

bars = np.add(wsmtp, wshtp).tolist()
r = [0,1,2,3,4]

ind   = np.arange(N) # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, wsmtp, width)
p2 = plt.bar(ind, wshtp, width,  bottom=wsmtp)
p3 = plt.bar(ind, wsatp, width,  bottom=bars)

plt.ylabel('Amount of people')
plt.title('Wealth segements by age')
plt.xticks(ind, ('q1', 'q2', 'q3', 'q4'))
plt.yticks(np.arange(0, 1500, 100))
plt.legend((p1[0], p2[0], p3[0]), ('Mass', 'High Net', 'Affluent'))

plt.show()

# %%
df["owns_car"].value_counts()
# Out:
# Yes    2023
# No     1976
# Name: owns_car, dtype: int64
